# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %% [markdown]
# # Open a particular image from a path

# %%
img = np.array(Image.open('DS_image.webp'))
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.show()

# %% [markdown]
# # Rotate that image by 90 (deg)

# %%
plt.imshow(np.rot90(img))

# %% [markdown]
# # Crop the image by half of its original size

# %%
img.shape
# Out:
# (934, 1400, 3)

# %%
from PIL import Image    
n = Image.open("DS_image.webp")

left = 0
top = 0
right = 800
bottom = 400
 
im1 = n.crop((left, top, right, bottom))
 
plt.imshow(im1)

# %% [markdown]
# # Pasting an image on another image

# %%
img1 = Image.open(r"DS_image.webp")
img2 = Image.open(r"Image-2.jpg")
  
img1.paste(img2, (800,200))
  
#img1.show()
plt.imshow(img1)

# %% [markdown]
# # Transpose the image

# %%
import cv2
img = cv2.imread('DS_image.webp')

# transpose the input image
image = cv2.transpose(img)

# Displaying the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("transposed Image")
plt.show()

# %% [markdown]
# # Use pytesseract to read text from an image

# %%
import pytesseract
from PIL import Image

# %%
image = cv2.imread('img5.png')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

image = cv2.imread('img5.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (3,3), 0)
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)
invert = 255 - opening

data = pytesseract.image_to_string(invert, lang='eng', config='--psm 6')
print(data)

cv2.imshow('thresh', thresh)
cv2.imshow('opening', opening)
cv2.imshow('invert', invert)
cv2.waitKey()
# Out:
# | LOVE
# TESSERACT
